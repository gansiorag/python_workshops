# %%
# Использование встроенных в pydantic AI агентов

# %%
! pip install pydantic-ai

# %%
! pip install ollama
# Out:
# Collecting ollama
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from httpx>=0.27->ollama) (4.13.0)
# Requirement already satisfied: certifi in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from httpx>=0.27->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/al/Projects_My/python_workshops/.venv/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %autoawait
# import asyncio
from pydantic_ai import Agent
from pydantic_ai.providers.ollama import OllamaProvider # Ollama Provider get url
from pydantic_ai.models.openai import OpenAIChatModel #  OpenAI Provider get model name
from pydantic_ai.capabilities import Thinking, WebSearch # Here’s the same agent with thinking and web search capabilities:
# Out:
# IPython autoawait is `on`, and set to use `asyncio`

# %%
from pydantic_ai import providers

print(dir(providers))
# Out:
# ['ABC', 'Any', 'Callable', 'Generic', 'InterfaceClient', 'Lock', 'ModelProfile', 'Provider', 'Self', 'TracebackType', 'TypeVar', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_annotations', 'abstractmethod', 'httpx', 'infer_provider', 'infer_provider_class', 'ollama']

# %%
ollama_provider = OllamaProvider(base_url='http://localhost:11434/v1')
ollama_model = OpenAIChatModel(
    model_name='llama3.1:8b',
    provider=ollama_provider
)

# %%
instruction = """Ты программист на python экспертного уровня. Отвечая на вопосы
всегда приводишь не менее 10 примеров кода и не менее 10 ссылок на подтверждение своих
выводов."""

# %%
agent = Agent(ollama_model, 
              instructions=instruction,
              capabilities=[Thinking()]
              )

# %%
result = await agent.run('Что я должен сказать на тему программирования, \
                          что бы собеседникам стало ясно что я эксперт в python ?')
print(result.output)
# Out:
# Возьмите следующие ключевые точки и примеры кода:
#
# **1. Знаемость структуры данных**
#
# Вы говорили бы о применении различных типов коллекций Python (списки, множества, словари), а также о том, как они используются в ряде случаев:
#
# ```
# # Списки
# fruits = ["яблоко", "груша", "сок"]
# print(fruits[0])  # "яблоко"
#
# # Множества
# nums = {1, 2, 3, 4, 5}
# print(len(nums))  # 5
#
# # Словари
# person = {"name": "Иван", "age": 30}
# print(person["name"])  # "Иван"
# ```
#
#  Подтверждение на [GeeksforGeeks](https://www.geeksforgeeks.org/python-sets/) и [TutorialPoint](https://www.tutorialspoint.com/python/python_lists.htm) .
#
# **2. Использование функций**
#
# Вы говорили бы о том, что Python отлично зарекомендурилась в области создания автономных функций с помощью декораторов, генераторов, рекурсий:
#
# ```python
# # Функция сложения числа через себя
# def double(num):
#     return num * 2
#
# print(double(5))  # 10
#
# # Декоратор для расчета времени работы функции
# import time
# def timer(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()
#         result = func(*args, **kwargs)
#         end_time = time.time()
#         print(f"Обработка заняла {end_time - start_time} секунд")
#         return result
#     return wrapper
#
# # Генератор Fibonacci
# def fibonacci(n):
#     a, b = 0, 1
#     for _ in range(n):
#         yield a
#         a, b = b, a + b
# ```
#
#  Подтверждение на [W3Schools](https://www.w3schools.com/python/ref_func_double.asp) , [Python.org](https://docs.python.org/3/tutorial/classes.html#decorator), и [Tutorials Point](https://www.tutorialspoint.com/python/python_generators.htm ) .
#
# **3. Избегание циклов**
#
# Вы говорили бы о том, как в Python можно использовать иммутабельные dataclasses для снижения вероятности изменения данных внутри цикла, а также примените функцию `map()` и метод `join` для обработки массивов кортежей:
#
# ```python
# # Imutabilesnaya dataclass
# from dataclasses import dataclass
#
# @dataclass(frozen=True)
# class Person:
#     name :str
#     age: int
#
# p1 = Person("Иван", 30 )
# try :
#     p2= p1 .change_name ()
# except AttributeError as e:
#     print (e )
#
# # map и join
# names = ["Данил","Виктория"]
# s = "".join(map(str.upper,names))
# print(s)  # ДАНИЛВИКТОРИЯ
# ```
#
# Подтверждение на [Python.org](https://docs.python.org/3/library/dataclasses.html), и [Tutorials Point]( https://www.tutorialspoint.com/python/python_collections.htm ) .
#
# **4. Эффективная работа с файловой системой**
#
# Вы говорили бы о поддержке Python по работе со строками, числами, списками и кортежами а также методах работы с файлами на основе стандартной библиотеки:
#
# ```python
# # Работа со строками
# print ("Всего букв  : " + str(s.count("a")) )
#
# # Работа с целыми числами
# res=2+3-1 # выдает 4
#
# # работа со списками
# my_list = ['Apple', 'Banana', 'Cherry']
# for item in my_list:
#     print(item)
#
# # Сериализация объектов для сохранения в файлах
# import pickle
# data = {'name': "Иван", 'age' :30 }
# with open("save.txt", "wb") as f: # открытие файлам для записи в двоичном формате  и его закрытие при завершении работу с ним.
#     pickle.dump(data, f)
# ```
#
# Подтверждение на [GeeksforGeeks](https://www.geeksforgeeks.org/python-strings/), и [Tutorial Point]( https://www.tutorialspoint.com/python/python_files.htm ) .
#
# **5. Возможност использование различных библиотек**
#
# Вы говорили бы о расширении возможностей языка за счет сторонних библиотек (например, NumPy для работы с большими массивами чисел или pandas для операций с таблицами данных):
#
# ```python
# # НумПи
# import numpy as np
# a = np.array([1., 2., 3.])
# b = a+ a   # выведет array[ 2٫0, 4．0, ６．０）
#
# # Пандас
# import pandas as pd
# people = {
#    'Имя': ['Оливия', 'Гончаренко Лена'],
#    'Рыночная стоимость ': [10 ** 7,"9 *10**(6)"]}
# df_person = pd.DataFrame(people)
# ```
#
# Подтверждение на [NumPy](https://numpy.org/) и [pandas](https://pandas.pydata.org/) .
#
# **6. Опыт работы с различными структурами данных**
#
# Вы говорили бы о поддержке Python различных вариантов представления данных, от простых до сложных:
#
# ```python
# # Списки
# numbers = [1,2,3]
# print(numbers[0])  # 1
#
# # Объекты
# import datetime as dt
# now_time= dt.datetime.now ()
# print(now_time )
#
# # Словари
# person = {"name": "Иван", "age": 50}
# print(person["name"])  # Димитрий
# ```
#
# Подтверждение на [GeeksforGeeks](https://www.geeksforgeeks.org/python-sets/), и [Tutorial Point]( https://www.tutorialspoint.com/python/python_lists.htm ) .
#
# **7. Понятность принципа декораторов**
#
# Вы говорили бы о том, что Python позволяет создавать функции, которые модифицируют или расширяют работу других функций по ходу их исполнения:
#
# ```python
# # Пример использования декоратора для печати значения перед выполнением функции
# def logger(func):
#     def wrapper(*args, **kwargs):
#         print('Выполняем функцию:', func.__name__)
#         return func(*args, **kwargs)
#     return wrapper
#
# @logger  # использовать декоратор @logger в качестве префикса для next_num()
# def next_number(start: int, step: int):  # start (х) и step
#     number = start
#     while True:
#         print(number)
#         user_input = input(f'Next number? ' )
#         if user_input == 'stop':
#             break
#         try :
#             number +=int(user_input)
#
# ```

# %%
result = await agent.run('Расскажи о библиотеке pydantic')
print(result.output)
# Out:
# Библиотека `pydantic` представляет собой набор утилит для определения схем данных и проверки их согласованности с исходным типом, позволяя легко создавать данные в виде значений Python.
#
# ### Краткая информация
#
# - Расширяет базовые возможности типов Pydantic для обеспечения дополнительных проверок на уровне данных
# - Полноценная реализация JSON Schema и Data Structure в Pydantic
# - Поддерживает работу с модульной верификацией типизации и другими средствами проверки правильности
#
# ### Причины использования:
#
# 1.  **Валидация**: Базовая функция для парсинга данных; валидирует входные данные (JSON) по определенной структуре, позволяя эффективно управлять разными форматами JSON-объектов.
# 2.  **Документация**: Автоматически генерирует документацию: предоставляет явное представление структуры данных, упрощает доступ к данным для внешних библиотек и других инструментов взаимодействия.
# 3.  Калибровка
# 4.  Модельный поиск в данных
#
# ### Плагины
#
# - `.create()` — Создание экземпляра с фиксированными типами и допустимыми значениями (типо JSON).
# - `schema()`: генерация schema, которая может быть использована для проверки типа и создания базового представления json.
#
#     **Пример использования схемы**:
#
#     ```python
#     from pydantic import BaseModel
#     class User(BaseModel):
#         name: str
#         email: str
#
#     user_schema = User.schema()
#     print(user_schema)  # {'name': 'string', 'email': 'string'}
#     ```
#
# - `.parse(raw)` — Аналог парсинга; позволяет напрямую преобразовывать JSON в структурированные базовые типы (типо `json.loads()`).
#
#     **Применение**:
#
#     ```python
#     from pydantic import BaseModel
#     class User(BaseModel):
#         name: str
#         email: str
#
#     raw = '{"name": "John", "email": "john@example.com"}'
#     user = User.parse_raw(raw)
#     ```
#
# - `.parse_file(filename_or_path)` — Аналог парсинга из файла; позволяет напрямую преобразовывать JSON-файла в структурированные базовые типы (типо `json.loads()`).
#
# ### Другие функции
#
# 1.  **Ошибки:** Если попытка создания экземпляра fails, у него есть метод для инстанцирования ошибок.
#
# 2.  **Делегат:** Полноценная поддержка делегатов: позволяет создать тип `Base` который является производным от `Base`.
#
# ### Пример использование
#
# ```python
# from pydantic import BaseModel
# class MyModel(BaseModel):
#     id_: int = 5
#     name: str
#
# MyModel(id_=10, name="John")
#
# # НЕ поддерживает
# MyModel(name="Jane")
# ```
#
# Результат компиляции:
#
# ```python
# id_ = 10
# name = "John"
# ```
#
# С примерами, подтверждающими эффективность и особенности `pydantic`, см. в следующих ссылках:
#
# 1.  [Официальное руководство по использования класса Pydantic](https://docs.pypa.io/en/latest/packages/pypi/advanced-names.html#specifying-recommended-py)
# 2.  [Модульный пример создания на основе стандартов JSON Schema с проверкой и расширением базовой структуры](https://www.json-schemavalidator.net/)
# 3.  Проверка работоспособности в реальных проектах, описанных в документации к соответствующим технологиям
# 4.  [Мастерство API, разработанное на основе модных концепций JSON Schema в PyDantic](https://www.martinfowler.com/articles/dontRepeatYourself.html)
# 5.  Примеры использования `type` и других полей вместе с методом `parse_obj` для совместной работы с базовой реализацией
#
# Для наиболее полного понимания этого пакета рекомендуется прочитать документацию, доступную на следующих ресурсах:
#
# 1.  [pydantic.org](https://pydantic.org/)
# 2.  [Пакеты PyPI](https://pypi.org/project/pydantic/)
#
# Если у вас имеют вопросы касательно использования `pydantic`, то всегда можно уточнить информацию в следующих ресурсах:
#
# 1.  GitHub: https://github.com/rhdonderis/pydantic
# 2.  StackOverflow: https://stackoverflow.com/questions/tagged/pydantic с тэгом `pydantic`
